# %% [markdown]
# <a href="https://colab.research.google.com/github/kandgesid/Data-Science-and-ML-projects/blob/master/Object_counting_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Taken from [counting API](https://github.com/ahmetozlu/tensorflow_object_counting_api.git)

# %%
# !git clone https://github.com/ahmetozlu/tensorflow_object_counting_api.git
# Out:
# Cloning into 'tensorflow_object_counting_api'...
# remote: Enumerating objects: 1025, done.
# remote: Total 1025 (delta 0), reused 0 (delta 0), pack-reused 1025
# Receiving objects: 100% (1025/1025), 331.15 MiB | 31.45 MiB/s, done.
# Resolving deltas: 100% (481/481), done.
# Checking out files: 100% (559/559), done.

# %%
# %tensorflow_version 1.x
import tensorflow as tf
tf.__version__
# Out:
# TensorFlow 1.x selected.
# '1.15.2'

# %%
# %cd ../
# Out:
# /content

# %%
# !git clone https://github.com/tensorflow/models.git
# !git clone https://github.com/cocodataset/cocoapi.git
# !cd cocoapi/PythonAPI; make; cp -r pycocotools /content/models/research/
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 34285 (delta 5), reused 14 (delta 0), pack-reused 34261
# Receiving objects: 100% (34285/34285), 512.51 MiB | 31.89 MiB/s, done.
# Resolving deltas: 100% (22134/22134), done.
# Checking out files: 100% (2484/2484), done.
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 1.64 MiB/s, done.
# Resolving deltas: 100% (576/576), done.
# python setup.py build_ext --inplace
# running build_ext
# cythoning pycocotools/_mask.pyx to pycocotools/_mask.c
# ...

# %%
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# !pip install Cython
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# python-tk is already the newest version (2.7.17-1~18.04).
# The following additional packages will be installed:
#   python-bs4 python-chardet python-html5lib python-olefile
#   python-pkg-resources python-six python-webencodings
# Suggested packages:
#   python-genshi python-lxml-dbg python-lxml-doc python-pil-doc python-pil-dbg
#   python-setuptools
# The following NEW packages will be installed:
#   python-bs4 python-chardet python-html5lib python-lxml python-olefile
#   python-pil python-pkg-resources python-six python-webencodings
# 0 upgraded, 9 newly installed, 0 to remove and 25 not upgraded.
# Need to get 1,818 kB of archives.
# After this operation, 7,685 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-bs4 all 4.6.0-1 [67.9 kB]
# ...

# %%
# %cd /content/models/research/
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/models/research

# %%
# !python setup.py build
# !python setup.py install
# Out:
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/object_detection
# copying object_detection/model_main.py -> build/lib/object_detection
# copying object_detection/exporter.py -> build/lib/object_detection
# copying object_detection/model_hparams.py -> build/lib/object_detection
# copying object_detection/inputs.py -> build/lib/object_detection
# copying object_detection/model_tpu_main.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph.py -> build/lib/object_detection
# copying object_detection/eval_util_test.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph_lib.py -> build/lib/object_detection
# copying object_detection/model_lib_v2_test.py -> build/lib/object_detection
# copying object_detection/model_lib_test.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph_lib_test.py -> build/lib/object_detection
# ...

# %%
# %cd '/content/tensorflow_object_counting_api'
# Out:
# /content/tensorflow_object_counting_api

# %%
# !python /content/tensorflow_object_counting_api/pedestrian_counting.py
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")
# WARNING:tensorflow:From /content/tensorflow_object_counting_api/utils/backbone.py:38: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From /content/tensorflow_object_counting_api/utils/backbone.py:39: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /content/tensorflow_object_counting_api/api/object_counting_api.py:38: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-05-01 11:37:39.211375: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# !python /content/tensorflow_object_counting_api/real_time_counting.py
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")
# WARNING:tensorflow:From /content/tensorflow_object_counting_api/utils/backbone.py:38: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From /content/tensorflow_object_counting_api/utils/backbone.py:39: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /content/tensorflow_object_counting_api/api/object_counting_api.py:263: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-05-01 11:52:40.741427: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# !python /content/tensorflow_object_counting_api/real_time_counting_targeted_object.py
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")
# WARNING:tensorflow:From /content/tensorflow_object_counting_api/utils/backbone.py:38: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From /content/tensorflow_object_counting_api/utils/backbone.py:39: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /content/tensorflow_object_counting_api/api/object_counting_api.py:419: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-05-01 12:17:41.281174: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# !python /content/tensorflow_object_counting_api/vehicle_counting.py
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")
# WARNING:tensorflow:From /content/tensorflow_object_counting_api/utils/backbone.py:38: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From /content/tensorflow_object_counting_api/utils/backbone.py:39: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /content/tensorflow_object_counting_api/api/object_counting_api.py:150: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-05-01 12:29:09.400062: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...
